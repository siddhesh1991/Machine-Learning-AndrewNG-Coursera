# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
path  = os.getcwd()
data = pd.read_csv(path+"\ex1data1.txt",header=None)
data.columns = ['X','Y']
data.head()
# Out:
#         X        Y
# 0  6.1101  17.5920
# 1  5.5277   9.1302
# 2  8.5186  13.6620
# 3  7.0032  11.8540
# 4  5.8598   6.8233

# %%
sns.set(rc={"figure.figsize": (10, 8)})
sns.regplot(data.X,data.Y,color='g', n_boot=500, y_jitter=.03)

# %%
data.insert(0, 'Intercept', 1)
data.head()
# Out:
#    Intercept       X        Y
# 0          1  6.1101  17.5920
# 1          1  5.5277   9.1302
# 2          1  8.5186  13.6620
# 3          1  7.0032  11.8540
# 4          1  5.8598   6.8233

# %% [markdown]
#  <img src="cost.png">

# %%
def computeCost(X,Y,weight):
    cost = (0.5*np.sum(np.power(np.dot(X,weight)-Y,2)))/len(X)
    return cost

# %%
X = data.values[:,:2]
Y= np.array(data.Y)

# %%
weight = np.array([0,0],dtype=np.float)
computeCost(X,Y,weight)
# Out:
# 32.072733877455676

# %% [markdown]
# ## replace
# <img src="weights.png">

# %%
def gradientDescent(X,Y,weight,alpha,iters):
    cost = np.zeros(iters)
    for j in range(iters):
        error = (np.dot(X,weight) - Y) #compute error and keep it same for each weight update for simultaneous update
        for i in range(len(weight)):
            effect = np.dot(X[:,i].transpose(),error)
            #term = np.multiply(error,X[:,i])#multiply error with each column and update weight
            dW = effect/len(X)
            weight[i] = weight[i] - (alpha*dW)
        cost[j] = computeCost(X,Y,weight)
    return weight,cost

# %%
#without loop
def gradientDescentVec(X,Y,weight,alpha,iters):
    cost = np.zeros(iters)
    for j in range(iters):
        error = (np.dot(X,weight) - Y) #compute error and keep it same for each weight update for simultaneous update
        effect = np.dot(X.transpose(),error) #or np.dot(error,X)
        dW = effect/len(X)
        weight = weight - (alpha*dW)
        cost[j] = computeCost(X,Y,weight)
    return weight,cost

# %%
weight = np.array([0,0],dtype=np.float)
new_weight, cost = gradientDescent(X,Y,weight,alpha = 0.0001, iters = 20000)
new_weight
# Out:
# array([-1.1236091 ,  0.91453892])

# %%
predict = np.dot(X,new_weight)
computeCost(X,Y,new_weight)
# Out:
# 5.1766034883051812

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(np.arange(500), cost[:500], 'r')
ax.set_xlabel('Iterations')
ax.set_ylabel('Cost')

# %%
plt.plot(data.X, data.Y,'b.',
        data.X,predict,'g-')
plt.xlabel('X')
plt.ylabel('Target')

# %%
#Multiple Regression
data2 = pd.read_csv(path+ '\ex1data2.txt', header=None, names=['X1', 'X2', 'Y'])
data2.head()
# Out:
#      X1  X2       Y
# 0  2104   3  399900
# 1  1600   3  329900
# 2  2400   3  369000
# 3  1416   2  232000
# 4  3000   4  539900

# %%
data2.iloc[:,:2] = (data2.iloc[:,:2] - data2.iloc[:,:2].mean()) / data2.iloc[:,:2].std()
data2.insert(0,'Intercept',1)
data2.head()
# Out:
#    Intercept        X1        X2       Y
# 0          1  0.130010 -0.223675  399900
# 1          1 -0.504190 -0.223675  329900
# 2          1  0.502476 -0.223675  369000
# 3          1 -0.735723 -1.537767  232000
# 4          1  1.257476  1.090417  539900

# %%
X_m = data2.values[:,:3]
Y_m = np.array(data2.Y)

# %%
weight_m = np.array([0,0,0],dtype=np.float)
new_weight_m, cost_m = gradientDescentVec(X_m,Y_m,weight_m,alpha = 0.01, iters = 1500)
new_weight_m
# Out:
# array([ 340412.56301439,  110540.56654627,   -6558.99054811])

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax.plot(np.arange(500), cost_m[:500], 'r')
ax.set_xlabel('Iterations')
ax.set_ylabel('Cost')

# %%
predict_m = np.dot(X_m,new_weight_m)
computeCost(X_m,Y_m,new_weight_m)
# Out:
# 2043283576.6373608

# %%
plt.scatter(Y_m,predict_m)
plt.xlabel('Target')
plt.ylabel('Prediction')

# %%
#SKLEARN
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X_m, Y_m)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
plt.scatter(Y_m,model.predict(X_m))
plt.xlabel('Target')
plt.ylabel('Prediction')

# %% [markdown]
# ## for ridge/lasso regression just the derivative equation will change for columns other than intercept to take penalty into account
